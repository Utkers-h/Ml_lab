# %% [markdown]
# # Pandas basic

# %%
import pandas as pd

url ="https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"

df = pd.read_csv(url)

print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.columns

#read each column
# df['Name'][4: 10]
# print(df.Name)
# df[['Name', 'Type 1', 'Legendary']]

#Read each row
# print(df.iloc[1])
print(df.iloc[3:5])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#Reading a specific location (r,c)
print(df.iloc[6,1])
# Out:
# Charizard

# %%
#iterating through each row
# for index,row in df.iterrows():
#     print(index,row['Name'])

# df.loc[df['Legendary']=="True"]
# df.loc[df['Type 1']=="Psychic"]

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Legendary')
# Out:
#        #                     Name    Type 1    Type 2   HP  Attack  Defense  \
# 0      1                Bulbasaur     Grass    Poison   45      49       49
# 511  460  AbomasnowMega Abomasnow     Grass       Ice   90     132      105
# 512  461                  Weavile      Dark       Ice   70     120       65
# 513  462                Magnezone  Electric     Steel   70      70      115
# 514  463               Lickilicky    Normal       NaN  110      85       95
# ..   ...                      ...       ...       ...  ...     ...      ...
# 431  386        DeoxysSpeed Forme   Psychic       NaN   50      95       90
# 163  150      MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# 162  150                   Mewtwo   Psychic       NaN  106     110       90
# 425  384                 Rayquaza    Dragon    Flying  105     150       90
# 799  721                Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1' , 'Attack'], ascending=[1,0]) 
# this will print type 1 in ascending order(alphabetical ) and attack in descending
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 137  127        PinsirMega Pinsir    Bug    Flying  65     155      120
# 19    15    BeedrillMega Beedrill    Bug    Poison  65     150       40
# 229  212        ScizorMega Scizor    Bug     Steel  70     150      140
# 650  589               Escavalier    Bug     Steel  70     135      105
# ..   ...                      ...    ...       ...  ..     ...      ...
# 405  370                  Luvdisc  Water       NaN  43      30       55
# 198  183                   Marill  Water     Fairy  70      20       50
# 508  458                  Mantyke  Water    Flying  45      20       50
# 381  349                   Feebas  Water       NaN  20      15       20
# 139  129                 Magikarp  Water       NaN  20      10       55
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Making changes to the data

# %%
df['Total'] = df['HP'] + df['Attack']+df['Defense']+df['Speed']
df.head(5)

#drop the column
df =df.drop(columns=['Total'])
df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
df['Total'] = df.iloc[:,4:10].sum(axis=1)
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df['Total'] = df.iloc[:,4:10].sum(axis=1)
cols = list(df.columns)
# Reordering the columns
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
#First 4 column -> last column -> rest of the columns
print(df.head(3))
# Out:
#    #       Name Type 1  Type 2  Legendary  Total  HP  Attack  Defense  \
# 0  1  Bulbasaur  Grass  Poison      False    591  45      49       49
# 1  2    Ivysaur  Grass  Poison      False    750  60      62       63
# 2  3   Venusaur  Grass  Poison      False    970  80      82       83
#
#    Sp. Atk  Sp. Def  Speed  Generation
# 0       65       65     45           1
# 1       80       80     60           1
# 2      100      100     80           1

# %%
new_df = df.loc[(df['Type 1']=='Psychic') & df.Legendary == True]
# new_df.to_csv('Filtered data')

# %%
#Filtering out mega pokemons
# df.loc[df.Name.str.contains('Mega')]
import re

# df.loc[df['Name'].str.contains('Mega')]
df.loc[df['Type 1'].str.contains('Fire|Grass',regex=True)]

# names with pi at the start
# df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I,regex=True)]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %% [markdown]
# # Conditional Change

# %%
#will change all the fire type to flame type

# df.loc[df['Type 1']== 'Fire', 'Type 1' ]='flame'

# df.loc[df['Total']> 500 , ['Generation','Legendary']] = ['test1','test2']
df= pd.read_csv(url)
# df

# %%
#Aggregate functions
# df.groupby(['Type 1']).mean(numeric_only=True)
# df.groupby(['Type 1']).mean(numeric_only=True).sort_values('Attack',ascending=False)
df.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        69    69      52   69      69       69       69       69     69
# Dark       31    31      21   31      31       31       31       31     31
# Dragon     32    32      21   32      32       32       32       32     32
# Electric   44    44      17   44      44       44       44       44     44
# Fairy      17    17       2   17      17       17       17       17     17
# Fighting   27    27       7   27      27       27       27       27     27
# Fire       52    52      24   52      52       52       52       52     52
# Flying      4     4       2    4       4        4        4        4      4
# Ghost      32    32      22   32      32       32       32       32     32
# Grass      70    70      37   70      70       70       70       70     70
# Ground     32    32      19   32      32       32       32       32     32
# ...
